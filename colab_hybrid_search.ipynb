# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 48.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/hybrid_search
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/hybrid_search

# %%
# !python create_faiss_from_csv.py
# Out:
# 2025-10-19 20:58:14.653407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760907494.682225    4487 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760907494.691081    4487 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760907494.709852    4487 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760907494.709894    4487 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760907494.709899    4487 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760907494.709902    4487 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-19 20:58:14.715686: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [1/4] Sampling 60000 training texts from wikipedia_sample_150k_with_ids.csv …
# Processing chunk 0
# Processing chunk 1
# Processing chunk 2
# Processing chunk 3
# Processing chunk 4
# Processing chunk 5
# Processing chunk 6
# Processing chunk 7
# Processing chunk 8
# Processing chunk 9
# Processing chunk 10
# Processing chunk 11
# Processing chunk 12
# Processing chunk 13
# Processing chunk 14
# Sampled 60000 texts
# [2/4] Embedding training texts …
# modules.json: 100% 349/349 [00:00<00:00, 1.31MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 739kB/s]
# README.md: 10.5kB [00:00, 19.6MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 213kB/s]
# config.json: 100% 612/612 [00:00<00:00, 4.21MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:01<00:00, 56.4MB/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.99MB/s]
# vocab.txt: 232kB [00:00, 9.35MB/s]
# tokenizer.json: 466kB [00:00, 24.6MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 796kB/s]
# config.json: 100% 190/190 [00:00<00:00, 837kB/s]
# Training matrix: (60000, 384)
# [3/4] Creating & training IVF-PQ index …
# [4/4] Adding all vectors to index …
# Processing chunk 0
#   +10000 → ntotal=10000
# Processing chunk 1
#   +10000 → ntotal=20000
# Processing chunk 2
#   +10000 → ntotal=30000
# Processing chunk 3
#   +10000 → ntotal=40000
# Processing chunk 4
#   +10000 → ntotal=50000
# Processing chunk 5
#   +10000 → ntotal=60000
# Processing chunk 6
#   +10000 → ntotal=70000
# Processing chunk 7
#   +10000 → ntotal=80000
# Processing chunk 8
#   +10000 → ntotal=90000
# Processing chunk 9
#   +10000 → ntotal=100000
# Processing chunk 10
#   +10000 → ntotal=110000
# Processing chunk 11
#   +10000 → ntotal=120000
# Processing chunk 12
#   +10000 → ntotal=130000
# Processing chunk 13
#   +10000 → ntotal=140000
# Processing chunk 14
#   +10000 → ntotal=150000
# Done. Saved index at: index.faiss
# ntotal=150000
